# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np

# %%
driver = webdriver.Chrome('C:/Users/ASUS/Downloads/chromedriver_win32/chromedriver.exe')
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_9868/4100202580.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/ASUS/Downloads/chromedriver_win32/chromedriver.exe')

# %%
driver.get('https://www.google.com/')

# %%
inbox = driver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
inbox.send_keys('https://www.naukri.com/mnjuser/homepage')
inbox.send_keys(Keys.ENTER)
clickable = driver.find_element(By.XPATH, '//*[@id="tads"]/div/div/div/div/div[1]/a/div[1]/span')
clickable.click()

# %%
login = driver.find_element(By.XPATH, '//*[@id="root"]/div/header/div/span/a').click()

# %%
login_box = driver.find_element(By.XPATH, '//*[@id="usernameField"]')
login_box.send_keys('aniketterror30859@gmail.com')
login_pass = driver.find_element(By.XPATH, '//*[@id="passwordField"]')
login_pass.send_keys('Bot@123')
driver.find_element(By.XPATH, '//*[@id="loginForm"]/div[2]/div[3]/div/button[1]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="ni-gnb-header-section"]/div[3]/div[2]/div[1]/div/span').click()
search_bar= driver.find_element(By.XPATH, '//*[@id="ni-gnb-header-section"]/div[3]/div[2]/div[1]/div/div/div[1]/div/div/div/input')
search_bar.send_keys('data scientist, data analyst, data engineer, machine learning engineer, business analyst')
search_bar.send_keys(Keys.ENTER)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
postings = soup.find_all('article', class_ = 'jobTuple')
link = []
for post in postings:
    link.append(post.find('a', class_ = 'title ellipsis').get('href'))
next_page = soup.find('a', class_ = 'fright fs14 btn-secondary br2').get('href')

# %%
while next_page:
    driver.get('https://www.naukri.com' + next_page)
    time.sleep(4)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    postings = soup.find_all('article', class_ = 'jobTuple')
    for post in postings:
        link.append(post.find('a', class_ = 'title ellipsis').get('href'))
    next_page = soup.find('a', class_ = 'fright fs14 btn-secondary br2').get('href')

# %%
df = pd.DataFrame({'Job_Title':[''], 'Company': [''], 'Rating': [''],'Experience':[''], 'Salary':[''], 'Location':[''],
                   'Posted_day':[''], 'Applicants':[''], 'Job_Description':[''], 'Skills':[''],
                   'role_by_company':[''], 'company_industry':['']})

# %%
init = time.time()
for i in link1:
    driver.get(i)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    try:
        title = soup.find('h1', class_ = 'jd-header-title').text
    except:
        title = np.nan
        pass
    try:
        company_name_block = soup.find('div', class_ = 'jd-header-comp-name')
        try:
            company_name = company_name_block.find('a', class_ = 'pad-rt-8').text
        except:
            company_name = np.nan
            pass
        try:
            rating = company_name_block.find('span', class_ = 'amb-rating pad-rt-4')
        except:
            rating = np.nan
            pass
    except:
        pass
    try:
        experience = soup.find('div', class_ = 'exp').text
    except:
        experience = np.nan
        pass
    try:
        salary = soup.find('div', class_ = 'salary').text
    except:
        salary = np.nan
        pass
    try:
        location = soup.find('div', class_ = 'loc').text
    except:
        location = np.nan
        pass
    try:
        info = soup.find_all('span', class_ = 'stat')
        posted = info[0].text
        applicants = info[2].text
    except:
        posted = np.nan
        applicants = np.nan
        pass
    try:
        desc = soup.find('div', class_ = 'dang-inner-html').text
    except:
        desc = np.nan
        pass
    try:
        skill_block = soup.find('div', class_ = 'key-skill')
        skill = skill_block.find_all('a')
        skills = []
        for i in skill:
            skills.append(i.text)
    except:
        skills.append(np.nan)
        pass
    try:
        other_detail_block = soup.find('div', 'other-details')
        other_details = role_mentioned.find_all('div', class_ = 'details')
        role = other_details[0].text
        industry = other_details[1].text
    except:
        role = np.nan
        industry = np.nan
    df = df.append({'Job_Title':title,'Company': company_name, 'Rating': rating, 'Experience':experience, 'Salary':salary, 'Location':location,
                   'Posted_day':posted, 'Applicants':applicants, 'Job_Description':desc, 'Skills':skills,
                   'role_by_company':role, 'company_industry':industry}, ignore_index=True)
end = time.time()
print(end-init)
# Out:
# 4856.8977863788605

# %%
df = df1

# %%
df
# Out:
#                                   Job_Title                 Company Rating  \
# 0
# 1                     AI/Data Product Owner   Wavelabs Technologies  [3.6]
# 2                     AI/Data Product Owner   Wavelabs Technologies  [3.6]
# 3                            Data Scientist  Talentstack Consulting   None
# 4                            Data Scientist                     GKN  [4.4]
# ...                                     ...                     ...    ...
# 2366                       Business Analyst        Dhanush Infotech  [3.8]
# 2367                       Business Analyst             People Tech  [3.3]
# 2368                       Business Analyst           Treebo Hotels  [3.7]
# 2369              Machine Learning Engineer              AM Infoweb  [3.8]
# 2370  Business Analyst - US State and Local  Innovee Consulting Llc   None
#
#        Experience                Salary  \
# 0
# 1         1 years         Not Disclosed
# 2         1 years         Not Disclosed
# ...

# %%
df
# Out:
#                   Job_Title                 Company Rating   Experience  \
# 0
# 1     AI/Data Product Owner   Wavelabs Technologies  [3.6]      1 years
# 2     AI/Data Product Owner   Wavelabs Technologies  [3.6]      1 years
# 3            Data Scientist  Talentstack Consulting   None  1 - 3 years
# 4            Data Scientist                     GKN  [4.4]  3 - 6 years
# ...                     ...                     ...    ...          ...
# 2849           Data Analyst      Infiwave Solutions  [4.5]  0 - 1 years
# 2850         Data scientist                SMEClabs  [4.8]  1 - 3 years
# 2851           Data Analyst                Fashalot   None  2 - 7 years
# 2852           Data Analyst            Leverage Edu  [3.8]  1 - 2 years
# 2853           data analyst       Disha Consultants  [4.6]  4 - 8 years
#
#                      Salary                         Location  \
# 0
# 1             Not Disclosed  Hyderabad/SecunderabadView More
# ...

# %%
df.to_csv('C:/Users/ASUS/Desktop/python_datasets/Untitled Folder/naukri.csv')
